# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re
spacy.cli.download("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.21)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.13.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/anaconda3/envs/20th_century/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.2.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Load 20th_century key events

# %%
# Load the key events .txt file
with open('Key_events_20th_century.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

# %%
#
NER = spacy.load("en_core_web_sm")
book = NER(data)

# %%
# Visualize identified entities
displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Russian Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ; and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , comprised initially of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria-Hungary.[1][2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ]   In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ended hostile actions against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The Bolsheviks negotiated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Treaty of Brest-Litovsk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , although it was a huge cost to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the treaty,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolshevik Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ceded the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baltic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  states to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and its province of
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kars Oblast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in the South Caucasus to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ottoman Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It also recognized the independence of Ukraine.[3] Although
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  shifted huge forces from the eastern to the western front after signing the treaty, it was unable to stop the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Allied
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  advance, especially with the entrance of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  troops in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1918.[4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ]   The war itself was also a chance for the combatant nations to show off their military strength and technological ingenuity. The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  introduced the machine gun,[5] U-boats[6] and deadly gases.[7] The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  first used the tank.[8] Both sides had a chance to test out their new aircraft to see if they could be used in warfare. It was widely believed that the war would be short. Unfortunately, since trenc

# %% [markdown]
# # Splitting Sentence Entities

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (   , The, 20th, century, changed, the, world,...
# 1  (The, World, Wars, sparked, tension, between, ...
# 2  (These, advancements, have, played, a, signifi...
# 3  (Historic, events, in, the, 20th, century,  , ...
# 4  (The, 1900s, saw, the, decade, herald, a, seri...
# 5  (1914, saw, the, completion, of, the, Panama, ...
# 6  (From, 1914, to, 1918, ,, the, First, World, W...
# 7  (The, First, World, War, (, or, simply, WWI, )...
# 8  (The, war, was, precipitated, by, the, Assassi...
# 9  (After, a, period, of, diplomatic, and, milita...
#
#                                             entities
# 0                                 [The 20th century]
# 1                     [the Cold War, the Space Race]
# 2                          [the 21st century, today]
# 3  [the 20th century  World, the beginning of the...
# 4                            [The 1900s, the decade]
# 5                           [1914, the Panama Canal]
# 6                [1914 to 1918, the First World War]
# 7  [The First World War, WWI, The Great War, July...
# 8  [Erzherzog Franz Ferdinand, Gavrilo Princip, Y...
# 9  [the July Crisis, the end of July 1914, Britis...

# %%
country_df = pd.read_csv("country_aliases.csv", index_col = 0)

# %%
country_df.head()
# Out:
#                  Aliases
# Country
# Abkhazia        abkhazia
# Afghanistan  afghanistan
# Albania          albania
# Algeria          algeria
# Andorra          andorra

# %% [markdown]
# # Filtering Data

# %%
# Define aliases for country names
#aliases = {
#    "united states": ["usa", "america", "u.s.", "united states of america"],
#    "united kingdom": ["uk", "britain", "england", "great britain"],
#    "south korea": ["korea", "republic of korea"],
#    "north korea": ["dprk"],
#    "china": ["prc", "peoples republic of china"],
 #   "russia": ["soviet union", "ussr"],
#}

# %%
# Function to filter out entities not of interest
#def filter_entity(ent_list, country_df, alias_col="Aliases"):
#    alias_set = set(country_df[alias_col].dropna().str.strip().str.lower())
#    return [ent for ent in ent_list if ent.lower().strip() in alias_set]

# %%
#print(country_df.columns)

# %%
#filtered = filter_entity(["united states", "russia", "united kingdom", ""], country_df)
#print(filtered[:5])

# %%
df_sentences['country_entities'] = df_sentences['entities'].apply(
    lambda x: filter_entity(x, country_df)
)

# %%
# Filter out sentences that don’t have any character entities
df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1136  (", The, forgotten, violence, that, helped, In...
# 1141  (", Indian, Independence, Day, :, everything, ...
# 1151  (", The, Philippines, ,, 1898–1946, |, US, Hou...
# 1185  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1227  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1291  (", Selling, ', Operation, Passage, to, Freedo...
# 1323  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1605  (", Anti, -, American, Behavior, in, the, Midd...
# 1610  (The, Rise, of, China, and, India, :, A, New, ...
# 1611               (Singapore, :, World, Scientific, .)
#
#                                                entities   country_entities
# 1136                                            [India]            [India]
# 1141  [Indian Independence Day, India, Pakistan, 70 ...  [India, Pakistan]
# 1151  [Philippines, 1898–1946, US House of Represent...      [Philippines]
# 1185  [Colonial Cartographies, Enduring Failures of ...      [Afghanistan]
# 1227  [Moldovans, Romania, Russia, the Politics of C...          [Romania]
# 1291  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1323  [Vietnam, the Battle of the Paris Peace Table,...          [Vietnam]
# 1605  [Anti-American, the Middle East, a Field Exper...          [Lebanon]
# 1610                         [The Rise of China, India]            [India]
# 1611                                        [Singapore]        [Singapore]

# %%
# Keep full names
df_sentences_filtered.loc[:, 'country_entities'] = df_sentences_filtered['country_entities'].apply(
    lambda x: [item.lower().strip() for item in x]
)

# %%
df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1136  (", The, forgotten, violence, that, helped, In...
# 1141  (", Indian, Independence, Day, :, everything, ...
# 1151  (", The, Philippines, ,, 1898–1946, |, US, Hou...
# 1185  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1227  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1291  (", Selling, ', Operation, Passage, to, Freedo...
# 1323  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1605  (", Anti, -, American, Behavior, in, the, Midd...
# 1610  (The, Rise, of, China, and, India, :, A, New, ...
# 1611               (Singapore, :, World, Scientific, .)
#
#                                                entities   country_entities
# 1136                                            [India]            [india]
# 1141  [Indian Independence Day, India, Pakistan, 70 ...  [india, pakistan]
# 1151  [Philippines, 1898–1946, US House of Represent...      [philippines]
# 1185  [Colonial Cartographies, Enduring Failures of ...      [afghanistan]
# 1227  [Moldovans, Romania, Russia, the Politics of C...          [romania]
# 1291  [Thomas Dooley, the Religious Overtones of Ear...          [vietnam]
# 1323  [Vietnam, the Battle of the Paris Peace Table,...          [vietnam]
# 1605  [Anti-American, the Middle East, a Field Exper...          [lebanon]
# 1610                         [The Rise of China, India]            [india]
# 1611                                        [Singapore]        [singapore]

# %% [markdown]
# # Creating Relationships

# %%
# Define window size
window_size = 5

# Create an empty list for edges
relationships = []

# Use .iloc to iterate over the filtered rows by position (not index values)
for i in range(len(df_sentences_filtered)):
    end_i = min(i + window_size, len(df_sentences_filtered))
    
    # Flatten all country_entities in this window
    country_list = sum(df_sentences_filtered.iloc[i:end_i]['country_entities'].tolist(), [])
    
    # Remove consecutive duplicates
    country_unique = [country_list[j] for j in range(len(country_list)) 
                      if j == 0 or country_list[j] != country_list[j - 1]]
    
    # Record pairwise relationships
    if len(country_unique) > 1:
        for idx in range(len(country_unique) - 1):
            relationships.append({
                "source": country_unique[idx],
                "target": country_unique[idx + 1]
            })

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#       source     target
# 0     france    germany
# 1    germany      italy
# 2    germany      italy
# 3      italy    germany
# 4    germany      italy
# ..       ...        ...
# 617  lebanon      india
# 618    india  singapore
# 619  lebanon      india
# 620    india  singapore
# 621    india  singapore
#
# [622 rows x 2 columns]

# %%
# Sort source and target alphabetically (A-B or B-A become the same)
relationships_df = pd.DataFrame(
    np.sort(relationship_df[['source', 'target']].values, axis=1),
    columns=['source', 'target']
)

relationships_df.head()
# Out:
#     source   target
# 0   france  germany
# 1  germany    italy
# 2  germany    italy
# 3  germany    italy
# 4  germany    italy

# %%
relationships_df.to_csv("country_relationships_20th_century.csv", index=False)
print("country_relationships_20th_century.csv is saved")
# Out:
# country_relationships_20th_century.csv is saved

# %%
# Count how often each relationship appears
edge_counts = relationships_df.value_counts().reset_index(name='weight')

edge_counts
# Out:
#          source        target  weight
# 0       germany         japan      31
# 1       germany        poland      28
# 2        france       germany      28
# 3       germany         italy      25
# 4         india         japan      18
# ..          ...           ...     ...
# 86      finland        poland       4
# 87        india     singapore       4
# 88        india  south africa       4
# 89         iran        israel       4
# 90  afghanistan   philippines       4
#
# [91 rows x 3 columns]

# %%
# Create the edge_counts DataFrame
edge_counts = relationships_df.value_counts().reset_index(name='weight')

# %%
edge_counts.to_csv("country_edge_counts.csv", index=False)
print("country_edge_counts.csv is now saved")
# Out:
# country_edge_counts.csv is now saved
